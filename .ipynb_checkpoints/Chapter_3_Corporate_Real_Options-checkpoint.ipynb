# %% [markdown]
# # Chapter 3: Corporate Real Options
#
# ## Key Concepts
# - Understand flexibility value through real options
# - Identify real options in business and in daily life
# - Calculate the value of various types of real options using real options theory
# - Model a business decision as a real option
# - Evaluate a business proposal based on real option theory

# %% [markdown]
# ## 1. Fundamentals

# %% [markdown]
# ### 1.1. Real Option: Investment Opportunities as Options

# %% [markdown]
# **Real Option**: Choices on whether and how to proceed with business investment opportunities.
# - Note that it is the **value of opportunities** that emerged from the investment not the value of the investment now.
#
# Real options are analogous to financial options:
# > An oil field concession is similar to an American call option:
# > - The concession gives the oil company the right to develop the field during a specific period,
# > - With an exercise price equal to the investment outlay needed to install the oil production facilities.
# > - The value of this timing flexibility depends on the prices of (futures contracts in) oil.
# > - Similar to dividends, the company misses an operational cash flow that would have been received if the option to develop the oil field was exercised early.
#
# Interestingly, if investment opportunities can be valued by either NPV/DCF or financial options methods, the risk of the investment may have different impacts
# - NPV/DCF: Higer Risk, Higher Required Return, Lowered Present Value
# - Real Option: Higer Risk, Higher Present Value

# %% [markdown]
# #### Comparison between a Call Option and a Real Option
#
# | Symbol | Call Option | Symbol | Real Option |
# | :-: | - : | :-: | - : |
# | $S$ | Stock Price | $V$ | PV of expected CF |
# | $K$ | Exercise Price | $I$ | PV of Investment Outlays |
# | $T$ | Time to Maturity | $ T $ | Length of Deferral Time |
# | $r$ | Risk-free rate | $r$ | Time Value of Money |
# | $\sigma$ | Volatility of Stock Returns | $\sigma$ | Volatility of Project's Return |

# %% [markdown]
# ### 1.2. Risk-neutral Valuation

# %% [markdown]
# The error in the traditional approach arises from the use of a single (or constant) risk-adjusted discount rate. Asymmetric claims on an asset do not have the same riskiness (and hence expected rate of return) as the underlying asset itself. Real options corrects for this error by transforming the probabilities.
#
#
#
# **The risk-neutral probabilities**
# - The probabilities that would prevail in a risk-neutral world (where any asset is expected to yield the risk-free rate of return)
#
# - It would allow discounting cash flows at the riskless rate, r.
#
# - For a Binomial Tree Model where $V^+$ and $V^-$ are the end-of-period values in the up (+) and down (-) states, the formula for the risk-neutral probability is:
#
# $$
# p = \frac{(1 + r) V - V^-}{V^+ - V^-}
# $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Figure 3.3 shows that the opportunity to invest provided by the
# proprietary license or patent is more valuable than an immediate investment commitment since it allows management the flexibility to
# defer investment for a year and invest only if developments (e.g., demand or prices) are favorable

# %% [markdown]
# ### 1.3. Common Corporate Real Options

# %% [markdown]
# | Category | Description | Typical Industry |
# | :--- | :--- | :--- |
# | Option to defer (Simple Option) | Management holds a lease on (or the option to buy) valuable land or natural resources. It can wait to see if output prices justify constructing a building or plant, or developing a field. | All natural resource extraction industries, real estate development, farming, paper products |
# | Growth option (compound option) |  An early investment (e.g., R & D, lease on undeveloped land or oil reserve or strategic acquisition) or a strategic investment is a prerequisite or a link in a chain of interrelated projects, opening up future growth opportunities (e.g., a new generation product or process, oil reserves, access to a new  market, stengthening of core capabilities, strategic positioning  investments). | All industries that involve sequential investment processes (e.g., pharmaceuticals, electronics, oil, chemicals etc.) |
# | Option to abandon | If market conditions decline severely, management can abandon current operations permanently and realize on secondary markets the resale value of capital equipment and other  assets. | Capital-intensive industries with tangible assets, such as airlines and railroads, financial services, and new product introductions in uncertain markets |
# | Options to expand, contract, or extend the life of a facility | If market demand turns out to be more favorable than expected, management may increase capacity or accelerate resource utilization. Management may also extend production if the life of the product is longer than expected. Conversely, management may reduce the scale of operations. | Facilities planning and construction in cyclical industries; fashion apparel; commercial real estate |
# | Option to temporarily shut down the production process | If prices or demand changes, management may change the product mix of the facility (“product flexibility”). Alternatively, the same outputs can be produced by different production processes or inputs (“process flexibility”).| Natural resource industries such as mine operations |
# | Option to switch (e.g., raw materials, final products) | If prices or demand changes, management may change the product mix of the facility (“product flexibility”). Alternatively, the same outputs can be produced by different production processes or inputs (“process flexibility”). | **Product switches**: Any goods sought in small batches or subject to volatile demand, e.g., consumer electronics, toys, specialty paper, machine parts, automobiles; **Input switches**: All feedstock-dependent facilities, e.g., oil, electric power (oil/gas), crop switching, sourcing. |
# | Option to default | If profits are less favorable than expected and the value of the firm declines below the promised bond repayments, the firm can go bankrupt. With this option to default, the liability of equity holders is limited to the equity invested in the firm. | All levered firms |
# | Staged financing | If the firm’s performance is less favorable than expected, the venture capitalist has the option to exit early. | Start-up ventures. Small firms operating in uncertain growing or emerging markets, requiring sequential investments. |

# %% [markdown]
# ## 2. Valuation of Real Options

# %% [markdown]
# ### 2.1.  The (Simple) Option to Defer
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The option to defer is important when making an irreversible investment decision under uncertainty.
#
# At maturity, the value of this option would equal its NPV when positive, or zero if management abandons the project:
#
# $$
# \text{Expanded NPV} = \max[\text{NPV}(V_t - I), \text{abandon}(0)]
# $$
#
# However, the option to defer is similar to American option: **if exercising the option early might generate positive cash flows before the maturity, it might not be desirable to delay the investment under the uncertainty**.

# %% [markdown]
# #### Option to Defer under Exogenous Competition
#
# The value of a firm’s investment opportunities is sometimes affected by **exogenous competitive value erosion**. Examples of such **shared real options** include the opportunity to introduce a new product impacted by introduction of close substitutes or to penetrate a new geographic market without barriers to competitive entry.
#
# Suppose for simplicity that the incumbent and its competitors participate equally in the collective opportunities of the industry, sharing both the necessary investment outlay for developing the technology of $I = 80$ million as well as the total market value of cash inflows (“size of the pie”), $V = 100$ million.
#
# ![image.png](attachment:image.png)
#
# The option value of the incumbent would be eroded by exogenous com-
# petitive entry, analogous to a dividend yield (here at 50%), that tends to reduce the value of its option. Incumbent firms may have an incentive to commit to invest early to be able to protect against such exogenous competitive value erosion and preempt competitors from exercising their shared rights.

# %% [markdown]
# ### Exercise
#
# > One of the major car manufacturers has also become interested in investing in electric cars. They are still in the early stages of developing a fully electric car and management is a bit skeptic about the profitability of the investment. The R&D program involved multiple stages and required immediate capital outlays, while the cash inflows would be expected at a later point in time, as shown in the figure below. Management uses an **opportunity cost of capital of 16%** and a **risk-free rate of 2%**. **Cash inflows are discounted with the cost of capital and cash outflows are discounted with the risk-free rate**.
#
# The management of the company is having doubts whether they should invest in the development of the new electric car. However, you mention to them that they do not have to commit to both stages immediately. Instead they could invest in the R&D stage to create the option to commercialize later when the circumstances are right (i.e. they have the option to invest in the commercial project).
#
# Suppose that the (gross) value of expected future cash inflows (V) may fluctuate in line with the random fluctuation in demand ($u$ = 1.4, $d$ = 0.7 per period). Also assume a risk-neutral probability of $p$ = 0.457.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The Static NPV is therefore

# %%
import numpy as np
import numpy_financial as npf

outflow = np.array([-20, -100, -1600 ])
inflow = np.array([0, 0, 0, 400, 800, 1200, 300 ])
coc = 0.16
rf_rate = 0.02

npv_outflow = np.sum([outflow[i] / (1 + rf_rate)**i for i in range(len(outflow))])
npv_inflow = np.sum([inflow[i] / (1 + coc)**i for i in range(len(inflow))])
npv_project = npv_outflow + npv_inflow
npv_project
# Out:
# -263.34502304886337

# %% [markdown]
# Expected Value of the opportunity to invest under risk neutral measure:

# %%
u = 1.4
d = 0.7
I = 1600
p = 0.457
f_pos_pos = np.max([npv_inflow * u ** 2 - I, 0])

f_pos_neg = np.max([npv_inflow * u * d - I, 0])

f_neg_neg = np.max([npv_inflow * d ** 2 - I, 0])


f_pos = (p * f_pos_pos + (1 - p) * f_pos_neg) / (1 + rf_rate)
f_neg = (p * f_pos_neg + (1 - p) * f_neg_neg) / (1 + rf_rate)
f = (p * f_pos + (1 - p) * f_neg) / (1 + rf_rate)
f
# Out:
# 226.71998561406102

# %% [markdown]
# Expected Value of the R & D programme = Expanded NPV =

# %%
R_D_outflow = outflow[:2]
value_R_D = np.max([f + np.sum([R_D_outflow[i] / (1 + rf_rate)**i for i in range(len(R_D_outflow))]),0])
value_R_D
# Out:
# 108.68076992778651

# %% [markdown]
# Expected Value of the Option to Invest = Expanded NPV - Static NPV =

# %%
value_R_D - npv_project
# Out:
# 372.0257929766499

# %% [markdown]
# ### 2.2. Option to Expand or Contract
#
# Once a project is undertaken, management may have the flexibility to alter it in various ways at different times during its life. The flexibility to expand or contract a project’s scale can be quite valuable.
#
# > When a firm buys vacant, undeveloped land, or when it builds a small plant in a new geographic location to position itself to develop a large market, it essentially acquires an expansion option (expanding the scale when the demand is high) as well as an contraction option (forgoing the investment when the demand is low).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Option to Expand:
#
# $$
# C =  \max[\text{NPV of Expansion} (eV - I_1' ), 0]
# $$
#
# Option to Contract:
#
# $$
# P =  \max[\text{NPV of Contraction} (R_c - cV ), 0]
# $$
#
# The expanded NPV of a project with both options at maturity:
#
# $$
# \text{Static NPV} + \max[\text{NPV of expansion} (eV + I_1' ), \text{NPV of contraction} (R_c - cV), \text{retain base-scale capacity} (0)]\\
# = \text{Static NPV} + C + P
# $$

# %% [markdown]
# ### Exercise
#
# >Let's consider that the online retailer has highly uncertain and remote cash inflows. The company has both the option to expand and the option to contract the operations in two years (T=2). The company can expand the scale of the operations with e = 50% of the value of the cash inflows. This is an exclusive opportunity to build an additional warehouse that involves making an expenditure, of E = \\$60m at t = 2. In addition the company can also contract by c = 50\% of the value and recover a value of R = \\$40m at t = 2. <br><br>
# > Suppose that the present value of the expected future cash inflows is equal to V0 = \\$100m and that this may fluctuate randomly with demand. The value V0 can go up with factor u = 1.25 or can go down with factor d = 0.8 per period. We further assume that the risk free rate is 5\%.

# %% [markdown]
# The risk-neutral probability is therefore:

# %%
V_0 = 100
rf_rate = 0.05
u = 1.25
d = 0.8
V_u = V_0 * u
V_d = V_0 * d
p = (V_0 * (1 + rf_rate) - V_d) / (V_u - V_d)
p
# Out:
# 0.5555555555555556

# %% [markdown]
# Option Value:

# %%
V_uu = V_u * u
V_ud = V_u * d
V_dd = V_0 * d * d

e = 0.5
E = 60
R = 40
c = 0.5

F_uu = np.max([e * V_uu - E, R - c * V_uu, 0])
F_ud = np.max([e * V_ud - E, R - c * V_ud, 0])
F_dd = np.max([e * V_dd - E, R - c * V_dd, 0])

F_u = (p * F_uu + (1 - p) * F_ud) / (1 + rf_rate)
F_d = (p * F_ud + (1 - p) * F_dd) / (1 + rf_rate)

F_0 = (p * F_u + (1 - p) * F_d) / (1 + rf_rate)
F_0
# Out:
# 6.507376613196719

# %% [markdown]
# Expanded PV = Static PV + F_0

# %%
F_0 + V_0
# Out:
# 106.50737661319673

# %% [markdown]
# ### 2.3. The Option to Abandon for Salvage or Switch Use
#
# ![image.png](attachment:image.png)

# %% [markdown]
# $$
# \text{Expanded PV} = \text{Static } V +  \max[\text{abandon} (A - V), \text{continue}].
# $$

# %% [markdown]
# ### Exercise
#
# > Consider a real options valuation concerning the abandonment of a business with real estate. The management of the business has the flexibility to decide to abandon the business in two years. If management decides to abandon the business it can sell the real estate and recover $A$ = 200m. The value of the business is uncertain. Suppose that the present value of the expected future cash inflows from production is equal to $V_0$ = 200m. This value fluctuates randomly with demand, $V$ can go up with factor $u$ = 1.8 or can go down with factor $d$ = 0.6 per period. Furthermore assume that the risk free rate is 3%.

# %% [markdown]
# The Risk-Neutral Probability:

# %%
V_0 = 200
A = 200
u = 1.8
d = 0.6
rf_rate = 0.03

p = ((1 + rf_rate) - d) / (u - d)
p
# Out:
# 0.35833333333333334

# %% [markdown]
# The end-node pay-offs

# %%
V_uu = 200 * u ** 2
V_dd = 200 * d ** 2
V_ud = 200 * d * u

F_uu = np.max([A - V_uu, 0])
F_ud = np.max([A - V_ud, 0])
F_dd = np.max([A - V_dd, 0])

[F_uu, F_ud, F_dd]
# Out:
# [0.0, 0.0, 128.0]

# %% [markdown]
# The value of the option to abandon

# %%
F_u = (p * F_uu + (1 - p) * F_ud) / (1 + rf_rate)
F_d = (p * F_ud + (1 - p) * F_dd) / (1 + rf_rate)

F_0 = (p * F_u + (1 - p) * F_d) / (1 + rf_rate)
F_0
# Out:
# 49.67689906892469

# %% [markdown]
# The expanded NPV:

# %%
F_0 + V_0
# Out:
# 249.67689906892468

# %% [markdown]
# Draft for quiz:

# %%
V_u = 125
V_0 = 100
rf_rate = 0.04

u = V_u / V_0
d = 1/u
p = ((1+rf_rate) - d) / (u - d)
p
# Out:
# 0.5333333333333333

# %%
1 / ((26 + np.sqrt(151)) / 35) * 100
# Out:
# 91.41196181703661

# %%
F_uu = 0
F_ud = 20
F_dd = 50

p = 0.5
rf_rate = 0.05

F_u = (p * F_uu + (1 - p) * F_ud) / (1 + rf_rate)
F_d = (p * F_ud + (1 - p) * F_dd) / (1 + rf_rate)

F_0 = (p * F_u + (1 - p) * F_d) / (1 + rf_rate)
F_0
# Out:
# 20.40816326530612

# %%
p =(80 * 1.02 - 62) / (104 - 62)

(104 - 80) * p  / 1.02
# Out:
# 10.980392156862742

# %%
V_0 = 100
rf_rate = 0.02
u = 1.4
d = 1/u

p = ((1 + rf_rate) - d)/(u-d)

V_uuu = V_0 * u**3
V_uud = V_0 * u**2 * d
V_udd = V_0 * u * d**2
V_ddd = V_0 * d**3

I = 130

F_uuu = np.max([ V_uuu - I, 0])
F_uud = np.max([ V_uud - I, 0])
F_udd = np.max([ V_udd - I, 0])
F_ddd = np.max([ V_ddd - I, 0])

F_uu = (p * F_uuu + (1 - p) * F_uud) / (1 + rf_rate)
F_ud = (p * F_uud + (1 - p) * F_udd) / (1 + rf_rate)
F_dd = (p * F_udd + (1 - p) * F_ddd) / (1 + rf_rate)

F_u = (p * F_uu + (1 - p) * F_ud) / (1 + rf_rate)
F_d = (p * F_ud + (1 - p) * F_dd) / (1 + rf_rate)

F_0 = (p * F_u + (1 - p) * F_d) / (1 + rf_rate)
# expanded present value
F_0 + V_0
# Out:
# 115.17216116715136
